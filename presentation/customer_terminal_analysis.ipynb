# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Set Matplotlib defaults
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True, figsize=(11, 5))
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=16,
    titlepad=10,
)
plot_params = dict(
    color="0.75",
    style=".-",
    markeredgecolor="0.25",
    markerfacecolor="0.25",
    legend=False,
)
# %config InlineBackend.figure_format = 'retina'

# %%
customers_og_df = pd.read_csv('./data/customers.csv')
customers_og_df = customers_og_df.set_index("CUSTOMER_ID")

terminals_og_df = pd.read_csv('./data/terminals.csv')
terminals_og_df = terminals_og_df.set_index("TERMINAL_ID")

# %%
transactions_train_og = pd.read_csv('./data/transactions_train.csv', usecols=['TX_ID','TERMINAL_ID','CUSTOMER_ID','TX_FRAUD'])

# %%
transactions_train_merged  = pd.merge(transactions_train_og,customers_og_df,on='CUSTOMER_ID')
transactions_train_merged.count()
# Out:
# TX_ID            1066440
# CUSTOMER_ID      1066440
# TERMINAL_ID      1066440
# TX_FRAUD         1066440
# x_customer_id    1066440
# y_customer_id    1066440
# dtype: int64

# %%
transactions_train_merged  = pd.merge(transactions_train_merged,terminals_og_df,on='TERMINAL_ID')
transactions_train_merged.count()
# Out:
# TX_ID             1066440
# CUSTOMER_ID       1066440
# TERMINAL_ID       1066440
# TX_FRAUD          1066440
# x_customer_id     1066440
# y_customer_id     1066440
# x_terminal_id     1066440
# y_terminal__id    1066440
# dtype: int64

# %%
transactions_train_merged.head()
# Out:
#                                       TX_ID       CUSTOMER_ID  TERMINAL_ID  \
# 0  c6dde46458f3d1cfeb9256f8add45a14fb349f8f  7323088226725338     55875360
# 1  988e8385f2934716ff5e57566617e077678b7ec9  7323088226725338     55875360
# 2  0726d4ff29dbcd4e21c4dbe5291ee4165d15d1c6  4362790219307564     55875360
# 3  998ec1dfa3664fbf40f8f2f5ad38e1bd71841baf  2376754785900600     55875360
# 4  a6df8a36e41707014adf056496e329709bee902a  2376754785900600     55875360
#
#    TX_FRAUD  x_customer_id  y_customer_id  x_terminal_id  y_terminal__id
# 0         0      27.712334      18.147509      27.628549       20.873479
# 1         0      27.712334      18.147509      27.628549       20.873479
# 2         0      30.270670      20.798376      27.628549       20.873479
# 3         0      31.512472      22.541913      27.628549       20.873479
# 4         1      31.512472      22.541913      27.628549       20.873479

# %%
transactions_train_merged.set_index('TX_ID')
# Out:
#                                                CUSTOMER_ID  TERMINAL_ID  \
# TX_ID
# c6dde46458f3d1cfeb9256f8add45a14fb349f8f  7323088226725338     55875360
# 988e8385f2934716ff5e57566617e077678b7ec9  7323088226725338     55875360
# 0726d4ff29dbcd4e21c4dbe5291ee4165d15d1c6  4362790219307564     55875360
# 998ec1dfa3664fbf40f8f2f5ad38e1bd71841baf  2376754785900600     55875360
# a6df8a36e41707014adf056496e329709bee902a  2376754785900600     55875360
# ...                                                    ...          ...
# 70072c846b4aca1c1dda9a1537ba43ae831db35f  7760361189551290     26508045
# cee6f272e7d83e61f647d268d728409e1b1d9ea3  4712914414618850     26508045
# 208ed1fcbefbbb2fc71851a2a04eaad9c2cc4ddc  3473580532934853     26508045
# eece6a88d031195d838725f91143c6841054616c    84525978769760     26508045
# c361d29a3c58c1e371ee0ef1c64b072f4396c5ad  4010654553006867     26508045
#
#                                           TX_FRAUD  x_customer_id  \
# TX_ID
# c6dde46458f3d1cfeb9256f8add45a14fb349f8f         0      27.712334
# 988e8385f2934716ff5e57566617e077678b7ec9         0      27.712334
# 0726d4ff29dbcd4e21c4dbe5291ee4165d15d1c6         0      30.270670
# 998ec1dfa3664fbf40f8f2f5ad38e1bd71841baf         0      31.512472
# a6df8a36e41707014adf056496e329709bee902a         1      31.512472
# ...                                            ...            ...
# 70072c846b4aca1c1dda9a1537ba43ae831db35f         0      60.422202
# cee6f272e7d83e61f647d268d728409e1b1d9ea3         0      61.728967
# 208ed1fcbefbbb2fc71851a2a04eaad9c2cc4ddc         0      65.997976
# eece6a88d031195d838725f91143c6841054616c         0      68.423755
# c361d29a3c58c1e371ee0ef1c64b072f4396c5ad         0      61.500840
#
#                                           y_customer_id  x_terminal_id  \
# TX_ID
# c6dde46458f3d1cfeb9256f8add45a14fb349f8f      18.147509      27.628549
# 988e8385f2934716ff5e57566617e077678b7ec9      18.147509      27.628549
# 0726d4ff29dbcd4e21c4dbe5291ee4165d15d1c6      20.798376      27.628549
# 998ec1dfa3664fbf40f8f2f5ad38e1bd71841baf      22.541913      27.628549
# a6df8a36e41707014adf056496e329709bee902a      22.541913      27.628549
# ...                                                 ...            ...
# 70072c846b4aca1c1dda9a1537ba43ae831db35f      49.066317      65.339428
# cee6f272e7d83e61f647d268d728409e1b1d9ea3      49.043844      65.339428
# 208ed1fcbefbbb2fc71851a2a04eaad9c2cc4ddc      49.402127      65.339428
# eece6a88d031195d838725f91143c6841054616c      47.196565      65.339428
# c361d29a3c58c1e371ee0ef1c64b072f4396c5ad      49.847704      65.339428
#
#                                           y_terminal__id
# TX_ID
# c6dde46458f3d1cfeb9256f8add45a14fb349f8f       20.873479
# 988e8385f2934716ff5e57566617e077678b7ec9       20.873479
# 0726d4ff29dbcd4e21c4dbe5291ee4165d15d1c6       20.873479
# 998ec1dfa3664fbf40f8f2f5ad38e1bd71841baf       20.873479
# a6df8a36e41707014adf056496e329709bee902a       20.873479
# ...                                                  ...
# 70072c846b4aca1c1dda9a1537ba43ae831db35f       49.604206
# cee6f272e7d83e61f647d268d728409e1b1d9ea3       49.604206
# 208ed1fcbefbbb2fc71851a2a04eaad9c2cc4ddc       49.604206
# eece6a88d031195d838725f91143c6841054616c       49.604206
# c361d29a3c58c1e371ee0ef1c64b072f4396c5ad       49.604206
#
# [1066440 rows x 7 columns]

# %% [markdown]
# ### Adding a column called distTC: which is the dsitance between the terminal and the customer

# %%
transactions_train_merged['distTC'] = np.sqrt( (transactions_train_merged.x_customer_id-transactions_train_merged.x_terminal_id)**2 + (transactions_train_merged.y_customer_id-transactions_train_merged.y_terminal__id)**2 )

# %%
transactions_train_merged.head()
# Out:
#                                       TX_ID       CUSTOMER_ID  TERMINAL_ID  \
# 0  c6dde46458f3d1cfeb9256f8add45a14fb349f8f  7323088226725338     55875360
# 1  988e8385f2934716ff5e57566617e077678b7ec9  7323088226725338     55875360
# 2  0726d4ff29dbcd4e21c4dbe5291ee4165d15d1c6  4362790219307564     55875360
# 3  998ec1dfa3664fbf40f8f2f5ad38e1bd71841baf  2376754785900600     55875360
# 4  a6df8a36e41707014adf056496e329709bee902a  2376754785900600     55875360
#
#    TX_FRAUD  x_customer_id  y_customer_id  x_terminal_id  y_terminal__id  \
# 0         0      27.712334      18.147509      27.628549       20.873479
# 1         0      27.712334      18.147509      27.628549       20.873479
# 2         0      30.270670      20.798376      27.628549       20.873479
# 3         0      31.512472      22.541913      27.628549       20.873479
# 4         1      31.512472      22.541913      27.628549       20.873479
#
#      distTC
# 0  2.727257
# 1  2.727257
# 2  2.643188
# 3  4.227118
# 4  4.227118

# %%
fraudalent_cases = transactions_train_merged[(transactions_train_merged['TX_FRAUD'] == 1)][['TX_ID','TX_FRAUD','distTC']]
authentic_cases = transactions_train_merged[(transactions_train_merged['TX_FRAUD'] == 0)][['TX_ID','TX_FRAUD','distTC']]

# %%
fraudalent_cases.describe()
# Out:
#        TX_FRAUD        distTC
# count   27564.0  27564.000000
# mean        1.0      3.302074
# std         0.0      1.188337
# min         1.0      0.000000
# 25%         1.0      2.472140
# 50%         1.0      3.496804
# 75%         1.0      4.304897
# max         1.0      4.999809

# %%
authentic_cases.describe()
# Out:
#         TX_FRAUD        distTC
# count  1038876.0  1.038876e+06
# mean         0.0  3.307505e+00
# std          0.0  1.190866e+00
# min          0.0  0.000000e+00
# 25%          0.0  2.462597e+00
# 50%          0.0  3.505528e+00
# 75%          0.0  4.315153e+00
# max          0.0  4.999990e+00

# %%
sns.barplot(x = np.arange(fraudalent_cases.size()), y= fraudalent_cases['distTC'])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\joshu\OneDrive\Documents\fraud_detection\customer_terminal_analysis.ipynb Cell 15 line <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/joshu/OneDrive/Documents/fraud_detection/customer_terminal_analysis.ipynb#X25sZmlsZQ%3D%3D?line=0'>1</a> sns.barplot(x = np.arange(len(fraudalent_cases)), y= fraudalent_cases['distTC'])
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:3190, in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3187 if ax is None:
#    3188     ax = plt.gca()
# -> 3190 plotter.plot(ax, kwargs)
#    3191 return ax
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:1640, in _BarPlotter.plot(self, ax, bar_kws)
#    1638 """Make the plot."""
#    1639 self.draw_bars(ax, bar_kws)
# -> 1640 self.annotate_axes(ax)
#    1641 if self.orient == "h":
#    1642     ax.invert_yaxis()
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\seaborn\categorical.py:365, in _CategoricalPlotter.annotate_axes(self, ax)
#     362     group_names = ["" for _ in range(len(self.plot_data))]
#     364 if self.orient == "v":
# --> 365     ax.set_xticks(np.arange(len(self.plot_data)))
#     366     ax.set_xticklabels(group_names)
#     367 else:
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axes\_base.py:73, in _axis_method_wrapper.__set_name__.<locals>.wrapper(self, *args, **kwargs)
#      72 def wrapper(self, *args, **kwargs):
# ---> 73     return get_method(self)(*args, **kwargs)
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axis.py:1834, in Axis.set_ticks(self, ticks, minor)
#    1832 else:
#    1833     self.set_major_locator(mticker.FixedLocator(ticks))
# -> 1834     return self.get_major_ticks(len(ticks))
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axis.py:1348, in Axis.get_major_ticks(self, numticks)
#    1344     numticks = len(self.get_majorticklocs())
#    1346 while len(self.majorTicks) < numticks:
#    1347     # Update the new tick label properties from the old.
# -> 1348     tick = self._get_tick(major=True)
#    1349     self.majorTicks.append(tick)
#    1350     self._copy_tick_props(self.majorTicks[0], tick)
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axis.py:2043, in XAxis._get_tick(self, major)
#    2041 else:
#    2042     tick_kw = self._minor_tick_kw
# -> 2043 return XTick(self.axes, 0, major=major, **tick_kw)
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\axis.py:427, in XTick.__init__(self, *args, **kwargs)
#     421 # x in data coords, y in axes coords
#     422 self.tick1line.set(
#     423     xdata=[0], ydata=[0],
#     424     transform=self.axes.get_xaxis_transform(which="tick1"),
#     425     marker=self._tickmarkers[0],
#     426 )
# --> 427 self.tick2line.set(
#     428     xdata=[0], ydata=[1],
#     429     transform=self.axes.get_xaxis_transform(which="tick2"),
#     430     marker=self._tickmarkers[1],
#     431 )
#     432 self.gridline.set(
#     433     xdata=[0, 0], ydata=[0, 1],
#     434     transform=self.axes.get_xaxis_transform(which="grid"),
#     435 )
#     436 # the y loc is 3 points below the min of y axis
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\artist.py:1179, in Artist.set(self, **kwargs)
#    1177 if move_color_to_start:
#    1178     kwargs = {"color": kwargs.pop("color"), **kwargs}
# -> 1179 return self.update(kwargs)
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\artist.py:1064, in Artist.update(self, props)
#    1061             if not callable(func):
#    1062                 raise AttributeError(f"{type(self).__name__!r} object "
#    1063                                      f"has no property {k!r}")
# -> 1064             ret.append(func(v))
#    1065 if ret:
#    1066     self.pchanged()
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\lines.py:1170, in Line2D.set_marker(self, marker)
#    1159 @docstring.interpd
#    1160 def set_marker(self, marker):
#    1161     """
#    1162     Set the line marker.
#    1163
#    (...)
#    1168         arguments.
#    1169     """
# -> 1170     self._marker = MarkerStyle(marker, self._marker.get_fillstyle())
#    1171     self.stale = True
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\markers.py:236, in MarkerStyle.__init__(self, marker, fillstyle)
#     234 self._marker_function = None
#     235 self._set_fillstyle(fillstyle)
# --> 236 self._set_marker(marker)
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\markers.py:335, in MarkerStyle._set_marker(self, marker)
#     333 if not isinstance(marker, MarkerStyle):
#     334     self._marker = marker
# --> 335     self._recache()
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\markers.py:252, in MarkerStyle._recache(self)
#     248 # Initial guess: Assume the marker is filled unless the fillstyle is
#     249 # set to 'none'. The marker function will override this for unfilled
#     250 # markers.
#     251 self._filled = self._fillstyle != 'none'
# --> 252 self._marker_function()
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\markers.py:698, in MarkerStyle._set_tickup(self)
#     697 def _set_tickup(self):
# --> 698     self._transform = Affine2D().scale(1.0, 1.0)
#     699     self._snap_threshold = 1.0
#     700     self._filled = False
#
# File c:\Users\joshu\AppData\Local\Programs\Python\Python39\lib\site-packages\matplotlib\transforms.py:1881, in Affine2D.__init__(self, matrix, **kwargs)
#    1878 if matrix is None:
#    1879     # A bit faster than np.identity(3).
#    1880     matrix = IdentityTransform._mtx.copy()
# -> 1881 self._mtx = matrix.copy()
#    1882 self._invalid = 0
#
# KeyboardInterrupt:
