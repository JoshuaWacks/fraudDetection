# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from dateutil.parser import parse
from sklearn.preprocessing import OrdinalEncoder
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import roc_auc_score
from sklearn.decomposition import PCA
from sklearn.neural_network import MLPRegressor
from imblearn.combine import SMOTEENN
from imblearn.over_sampling import ADASYN
from collections import Counter
from sklearn.preprocessing import MinMaxScaler
from xgboost import XGBClassifier

from sklearn.linear_model import LogisticRegression

# %%
feature_set =  'feature_set_4_normalised'
X_train = pd.read_csv( F'./data/{feature_set}/X_train_full.csv')
y_train = pd.read_csv( F'./data/{feature_set}/y_train.csv').values.ravel()

X_val = pd.read_csv( F'./data/{feature_set}/X_valid_full.csv')
y_val = pd.read_csv( F'./data/{feature_set}/y_valid.csv').values.ravel()

# %%
counter = Counter(y_train)
print("Before Sampling: {}".format(counter))

pos = Counter(y_train).get(1)
neg = Counter(y_train).get(0)
total = neg+pos

weight_for_0 = (1 / neg) * (total / 2.0)
weight_for_1 = (1 / pos) * (total / 2.0)

class_weight = {0: weight_for_0, 1: weight_for_1}

print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
# Out:
# Before Sampling: Counter({0.0: 727162, 1.0: 19346})
# Weight for class 0: 0.51
# Weight for class 1: 19.29

# %%
xgboost = XGBClassifier(n_estimators = 1000,random_state=42,n_jobs=-1)
eval_set = [(X_val, y_val)]
xgboost.fit(X_train, y_train, eval_metric="auc", eval_set=eval_set, early_stopping_rounds=100, verbose=True)
# Out:
# c:\Users\joshu\anaconda3\lib\site-packages\xgboost\sklearn.py:885: UserWarning: `eval_metric` in `fit` method is deprecated for better compatibility with scikit-learn, use `eval_metric` in constructor or`set_params` instead.
#   warnings.warn(
# c:\Users\joshu\anaconda3\lib\site-packages\xgboost\sklearn.py:885: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-auc:0.60859
# [1]	validation_0-auc:0.63701
# [2]	validation_0-auc:0.63639
# [3]	validation_0-auc:0.64081
# [4]	validation_0-auc:0.65303
# [5]	validation_0-auc:0.65376
# [6]	validation_0-auc:0.66503
# [7]	validation_0-auc:0.66618
# [8]	validation_0-auc:0.68525
# [9]	validation_0-auc:0.69232
# [10]	validation_0-auc:0.71123
# [11]	validation_0-auc:0.71150
# [12]	validation_0-auc:0.71186
# [13]	validation_0-auc:0.71766
# [14]	validation_0-auc:0.72370
# [15]	validation_0-auc:0.72826
# [16]	validation_0-auc:0.73454
# [17]	validation_0-auc:0.73663
# [18]	validation_0-auc:0.73659
# [19]	validation_0-auc:0.73638
# [20]	validation_0-auc:0.73732
# [21]	validation_0-auc:0.73853
# [22]	validation_0-auc:0.73908
# [23]	validation_0-auc:0.74199
# [24]	validation_0-auc:0.74306
# [25]	validation_0-auc:0.74530
# [26]	validation_0-auc:0.74529
# [27]	validation_0-auc:0.74806
# [28]	validation_0-auc:0.74829
# [29]	validation_0-auc:0.75028
# [30]	validation_0-auc:0.75222
# [31]	validation_0-auc:0.75228
# [32]	validation_0-auc:0.75180
# [33]	validation_0-auc:0.75283
# [34]	validation_0-auc:0.75399
# [35]	validation_0-auc:0.75418
# [36]	validation_0-auc:0.75540
# [37]	validation_0-auc:0.75607
# [38]	validation_0-auc:0.75802
# [39]	validation_0-auc:0.76159
# [40]	validation_0-auc:0.76364
# [41]	validation_0-auc:0.76267
# [42]	validation_0-auc:0.76401
# [43]	validation_0-auc:0.76621
# [44]	validation_0-auc:0.76623
# [45]	validation_0-auc:0.76746
# [46]	validation_0-auc:0.76710
# [47]	validation_0-auc:0.76669
# [48]	validation_0-auc:0.76729
# [49]	validation_0-auc:0.76706
# [50]	validation_0-auc:0.76659
# [51]	validation_0-auc:0.76819
# [52]	validation_0-auc:0.77018
# [53]	validation_0-auc:0.77046
# [54]	validation_0-auc:0.77344
# [55]	validation_0-auc:0.77611
# [56]	validation_0-auc:0.77921
# [57]	validation_0-auc:0.77907
# [58]	validation_0-auc:0.77896
# [59]	validation_0-auc:0.77985
# [60]	validation_0-auc:0.77980
# [61]	validation_0-auc:0.77941
# [62]	validation_0-auc:0.77941
# [63]	validation_0-auc:0.77964
# [64]	validation_0-auc:0.78074
# [65]	validation_0-auc:0.78088
# [66]	validation_0-auc:0.78335
# [67]	validation_0-auc:0.78463
# [68]	validation_0-auc:0.78539
# [69]	validation_0-auc:0.78567
# [70]	validation_0-auc:0.78704
# [71]	validation_0-auc:0.78898
# [72]	validation_0-auc:0.78928
# [73]	validation_0-auc:0.78926
# [74]	validation_0-auc:0.78913
# [75]	validation_0-auc:0.78962
# [76]	validation_0-auc:0.79022
# [77]	validation_0-auc:0.79008
# [78]	validation_0-auc:0.78968
# [79]	validation_0-auc:0.78990
# [80]	validation_0-auc:0.79281
# [81]	validation_0-auc:0.79350
# [82]	validation_0-auc:0.79393
# [83]	validation_0-auc:0.79524
# [84]	validation_0-auc:0.79514
# [85]	validation_0-auc:0.79529
# [86]	validation_0-auc:0.79524
# [87]	validation_0-auc:0.79592
# [88]	validation_0-auc:0.79580
# [89]	validation_0-auc:0.79754
# [90]	validation_0-auc:0.79722
# [91]	validation_0-auc:0.79723
# [92]	validation_0-auc:0.79711
# [93]	validation_0-auc:0.79713
# [94]	validation_0-auc:0.79676
# [95]	validation_0-auc:0.79791
# [96]	validation_0-auc:0.79766
# [97]	validation_0-auc:0.79808
# [98]	validation_0-auc:0.79914
# [99]	validation_0-auc:0.79954
# [100]	validation_0-auc:0.79939
# [101]	validation_0-auc:0.79920
# [102]	validation_0-auc:0.79917
# [103]	validation_0-auc:0.79937
# [104]	validation_0-auc:0.80146
# [105]	validation_0-auc:0.80338
# [106]	validation_0-auc:0.80477
# [107]	validation_0-auc:0.80651
# [108]	validation_0-auc:0.80767
# [109]	validation_0-auc:0.80782
# [110]	validation_0-auc:0.80773
# [111]	validation_0-auc:0.80770
# [112]	validation_0-auc:0.80959
# [113]	validation_0-auc:0.81057
# [114]	validation_0-auc:0.81071
# [115]	validation_0-auc:0.81184
# [116]	validation_0-auc:0.81200
# [117]	validation_0-auc:0.81223
# [118]	validation_0-auc:0.81395
# [119]	validation_0-auc:0.81468
# [120]	validation_0-auc:0.81477
# [121]	validation_0-auc:0.81527
# [122]	validation_0-auc:0.81612
# [123]	validation_0-auc:0.81674
# [124]	validation_0-auc:0.81647
# [125]	validation_0-auc:0.81622
# [126]	validation_0-auc:0.81651
# [127]	validation_0-auc:0.81623
# [128]	validation_0-auc:0.81628
# [129]	validation_0-auc:0.81628
# [130]	validation_0-auc:0.81597
# [131]	validation_0-auc:0.81589
# [132]	validation_0-auc:0.81624
# [133]	validation_0-auc:0.81719
# [134]	validation_0-auc:0.81734
# [135]	validation_0-auc:0.81763
# [136]	validation_0-auc:0.81740
# [137]	validation_0-auc:0.81728
# [138]	validation_0-auc:0.81712
# [139]	validation_0-auc:0.81802
# [140]	validation_0-auc:0.81789
# [141]	validation_0-auc:0.81788
# [142]	validation_0-auc:0.81740
# [143]	validation_0-auc:0.81897
# [144]	validation_0-auc:0.81860
# [145]	validation_0-auc:0.81854
# [146]	validation_0-auc:0.81892
# [147]	validation_0-auc:0.81927
# [148]	validation_0-auc:0.81949
# [149]	validation_0-auc:0.81953
# [150]	validation_0-auc:0.81956
# [151]	validation_0-auc:0.81937
# [152]	validation_0-auc:0.81926
# [153]	validation_0-auc:0.81897
# [154]	validation_0-auc:0.81889
# [155]	validation_0-auc:0.81878
# [156]	validation_0-auc:0.81870
# [157]	validation_0-auc:0.81855
# [158]	validation_0-auc:0.81846
# [159]	validation_0-auc:0.81849
# [160]	validation_0-auc:0.81890
# [161]	validation_0-auc:0.82037
# [162]	validation_0-auc:0.82089
# [163]	validation_0-auc:0.82104
# [164]	validation_0-auc:0.82093
# [165]	validation_0-auc:0.82090
# [166]	validation_0-auc:0.82081
# [167]	validation_0-auc:0.82096
# [168]	validation_0-auc:0.82103
# [169]	validation_0-auc:0.82097
# [170]	validation_0-auc:0.82154
# [171]	validation_0-auc:0.82165
# [172]	validation_0-auc:0.82160
# [173]	validation_0-auc:0.82147
# [174]	validation_0-auc:0.82220
# [175]	validation_0-auc:0.82179
# [176]	validation_0-auc:0.82218
# [177]	validation_0-auc:0.82343
# [178]	validation_0-auc:0.82347
# [179]	validation_0-auc:0.82467
# [180]	validation_0-auc:0.82468
# [181]	validation_0-auc:0.82447
# [182]	validation_0-auc:0.82522
# [183]	validation_0-auc:0.82524
# [184]	validation_0-auc:0.82575
# [185]	validation_0-auc:0.82637
# [186]	validation_0-auc:0.82722
# [187]	validation_0-auc:0.82721
# [188]	validation_0-auc:0.82731
# [189]	validation_0-auc:0.82794
# [190]	validation_0-auc:0.82918
# [191]	validation_0-auc:0.82932
# [192]	validation_0-auc:0.83002
# [193]	validation_0-auc:0.83038
# [194]	validation_0-auc:0.83040
# [195]	validation_0-auc:0.83047
# [196]	validation_0-auc:0.83099
# [197]	validation_0-auc:0.83142
# [198]	validation_0-auc:0.83168
# [199]	validation_0-auc:0.83219
# [200]	validation_0-auc:0.83228
# [201]	validation_0-auc:0.83209
# [202]	validation_0-auc:0.83209
# [203]	validation_0-auc:0.83199
# [204]	validation_0-auc:0.83214
# [205]	validation_0-auc:0.83200
# [206]	validation_0-auc:0.83200
# [207]	validation_0-auc:0.83198
# [208]	validation_0-auc:0.83182
# [209]	validation_0-auc:0.83167
# [210]	validation_0-auc:0.83161
# [211]	validation_0-auc:0.83156
# [212]	validation_0-auc:0.83141
# [213]	validation_0-auc:0.83129
# [214]	validation_0-auc:0.83132
# [215]	validation_0-auc:0.83136
# [216]	validation_0-auc:0.83127
# [217]	validation_0-auc:0.83175
# [218]	validation_0-auc:0.83297
# [219]	validation_0-auc:0.83320
# [220]	validation_0-auc:0.83330
# [221]	validation_0-auc:0.83451
# [222]	validation_0-auc:0.83549
# [223]	validation_0-auc:0.83553
# [224]	validation_0-auc:0.83522
# [225]	validation_0-auc:0.83517
# [226]	validation_0-auc:0.83499
# [227]	validation_0-auc:0.83495
# [228]	validation_0-auc:0.83532
# [229]	validation_0-auc:0.83535
# [230]	validation_0-auc:0.83507
# [231]	validation_0-auc:0.83528
# [232]	validation_0-auc:0.83508
# [233]	validation_0-auc:0.83514
# [234]	validation_0-auc:0.83509
# [235]	validation_0-auc:0.83480
# [236]	validation_0-auc:0.83468
# [237]	validation_0-auc:0.83462
# [238]	validation_0-auc:0.83462
# [239]	validation_0-auc:0.83495
# [240]	validation_0-auc:0.83479
# [241]	validation_0-auc:0.83472
# [242]	validation_0-auc:0.83451
# [243]	validation_0-auc:0.83460
# [244]	validation_0-auc:0.83452
# [245]	validation_0-auc:0.83430
# [246]	validation_0-auc:0.83418
# [247]	validation_0-auc:0.83400
# [248]	validation_0-auc:0.83388
# [249]	validation_0-auc:0.83386
# [250]	validation_0-auc:0.83411
# [251]	validation_0-auc:0.83397
# [252]	validation_0-auc:0.83386
# [253]	validation_0-auc:0.83418
# [254]	validation_0-auc:0.83409
# [255]	validation_0-auc:0.83447
# [256]	validation_0-auc:0.83455
# [257]	validation_0-auc:0.83442
# [258]	validation_0-auc:0.83453
# [259]	validation_0-auc:0.83488
# [260]	validation_0-auc:0.83610
# [261]	validation_0-auc:0.83634
# [262]	validation_0-auc:0.83639
# [263]	validation_0-auc:0.83732
# [264]	validation_0-auc:0.83768
# [265]	validation_0-auc:0.83852
# [266]	validation_0-auc:0.83896
# [267]	validation_0-auc:0.83889
# [268]	validation_0-auc:0.83891
# [269]	validation_0-auc:0.83887
# [270]	validation_0-auc:0.83949
# [271]	validation_0-auc:0.83949
# [272]	validation_0-auc:0.83943
# [273]	validation_0-auc:0.83930
# [274]	validation_0-auc:0.83935
# [275]	validation_0-auc:0.83993
# [276]	validation_0-auc:0.83986
# [277]	validation_0-auc:0.83974
# [278]	validation_0-auc:0.83993
# [279]	validation_0-auc:0.83994
# [280]	validation_0-auc:0.83992
# [281]	validation_0-auc:0.83970
# [282]	validation_0-auc:0.83948
# [283]	validation_0-auc:0.83914
# [284]	validation_0-auc:0.83897
# [285]	validation_0-auc:0.83932
# [286]	validation_0-auc:0.83925
# [287]	validation_0-auc:0.83964
# [288]	validation_0-auc:0.83964
# [289]	validation_0-auc:0.83962
# [290]	validation_0-auc:0.83952
# [291]	validation_0-auc:0.83950
# [292]	validation_0-auc:0.83980
# [293]	validation_0-auc:0.83987
# [294]	validation_0-auc:0.83970
# [295]	validation_0-auc:0.84029
# [296]	validation_0-auc:0.84009
# [297]	validation_0-auc:0.83997
# [298]	validation_0-auc:0.83992
# [299]	validation_0-auc:0.83989
# [300]	validation_0-auc:0.83992
# [301]	validation_0-auc:0.83991
# [302]	validation_0-auc:0.83984
# [303]	validation_0-auc:0.83998
# [304]	validation_0-auc:0.83990
# [305]	validation_0-auc:0.83983
# [306]	validation_0-auc:0.84059
# [307]	validation_0-auc:0.84073
# [308]	validation_0-auc:0.84100
# [309]	validation_0-auc:0.84106
# [310]	validation_0-auc:0.84133
# [311]	validation_0-auc:0.84131
# [312]	validation_0-auc:0.84114
# [313]	validation_0-auc:0.84190
# [314]	validation_0-auc:0.84170
# [315]	validation_0-auc:0.84156
# [316]	validation_0-auc:0.84164
# [317]	validation_0-auc:0.84174
# [318]	validation_0-auc:0.84155
# [319]	validation_0-auc:0.84148
# [320]	validation_0-auc:0.84136
# [321]	validation_0-auc:0.84115
# [322]	validation_0-auc:0.84124
# [323]	validation_0-auc:0.84146
# [324]	validation_0-auc:0.84168
# [325]	validation_0-auc:0.84162
# [326]	validation_0-auc:0.84157
# [327]	validation_0-auc:0.84151
# [328]	validation_0-auc:0.84200
# [329]	validation_0-auc:0.84189
# [330]	validation_0-auc:0.84168
# [331]	validation_0-auc:0.84171
# [332]	validation_0-auc:0.84162
# [333]	validation_0-auc:0.84161
# [334]	validation_0-auc:0.84167
# [335]	validation_0-auc:0.84153
# [336]	validation_0-auc:0.84150
# [337]	validation_0-auc:0.84132
# [338]	validation_0-auc:0.84126
# [339]	validation_0-auc:0.84133
# [340]	validation_0-auc:0.84131
# [341]	validation_0-auc:0.84128
# [342]	validation_0-auc:0.84107
# [343]	validation_0-auc:0.84111
# [344]	validation_0-auc:0.84112
# [345]	validation_0-auc:0.84106
# [346]	validation_0-auc:0.84182
# [347]	validation_0-auc:0.84192
# [348]	validation_0-auc:0.84178
# [349]	validation_0-auc:0.84176
# [350]	validation_0-auc:0.84158
# [351]	validation_0-auc:0.84150
# [352]	validation_0-auc:0.84140
# [353]	validation_0-auc:0.84144
# [354]	validation_0-auc:0.84127
# [355]	validation_0-auc:0.84137
# [356]	validation_0-auc:0.84188
# [357]	validation_0-auc:0.84186
# [358]	validation_0-auc:0.84231
# [359]	validation_0-auc:0.84235
# [360]	validation_0-auc:0.84231
# [361]	validation_0-auc:0.84240
# [362]	validation_0-auc:0.84233
# [363]	validation_0-auc:0.84235
# [364]	validation_0-auc:0.84230
# [365]	validation_0-auc:0.84263
# [366]	validation_0-auc:0.84269
# [367]	validation_0-auc:0.84263
# [368]	validation_0-auc:0.84287
# [369]	validation_0-auc:0.84286
# [370]	validation_0-auc:0.84292
# [371]	validation_0-auc:0.84279
# [372]	validation_0-auc:0.84279
# [373]	validation_0-auc:0.84316
# [374]	validation_0-auc:0.84315
# [375]	validation_0-auc:0.84344
# [376]	validation_0-auc:0.84363
# [377]	validation_0-auc:0.84349
# [378]	validation_0-auc:0.84338
# [379]	validation_0-auc:0.84340
# [380]	validation_0-auc:0.84328
# [381]	validation_0-auc:0.84318
# [382]	validation_0-auc:0.84307
# [383]	validation_0-auc:0.84313
# [384]	validation_0-auc:0.84350
# [385]	validation_0-auc:0.84338
# [386]	validation_0-auc:0.84322
# [387]	validation_0-auc:0.84314
# [388]	validation_0-auc:0.84306
# [389]	validation_0-auc:0.84303
# [390]	validation_0-auc:0.84309
# [391]	validation_0-auc:0.84321
# [392]	validation_0-auc:0.84363
# [393]	validation_0-auc:0.84382
# [394]	validation_0-auc:0.84417
# [395]	validation_0-auc:0.84419
# [396]	validation_0-auc:0.84414
# [397]	validation_0-auc:0.84430
# [398]	validation_0-auc:0.84465
# [399]	validation_0-auc:0.84444
# [400]	validation_0-auc:0.84442
# [401]	validation_0-auc:0.84457
# [402]	validation_0-auc:0.84468
# [403]	validation_0-auc:0.84479
# [404]	validation_0-auc:0.84508
# [405]	validation_0-auc:0.84532
# [406]	validation_0-auc:0.84525
# [407]	validation_0-auc:0.84545
# [408]	validation_0-auc:0.84535
# [409]	validation_0-auc:0.84531
# [410]	validation_0-auc:0.84530
# [411]	validation_0-auc:0.84529
# [412]	validation_0-auc:0.84515
# [413]	validation_0-auc:0.84503
# [414]	validation_0-auc:0.84516
# [415]	validation_0-auc:0.84520
# [416]	validation_0-auc:0.84552
# [417]	validation_0-auc:0.84546
# [418]	validation_0-auc:0.84544
# [419]	validation_0-auc:0.84534
# [420]	validation_0-auc:0.84531
# [421]	validation_0-auc:0.84534
# [422]	validation_0-auc:0.84558
# [423]	validation_0-auc:0.84539
# [424]	validation_0-auc:0.84553
# [425]	validation_0-auc:0.84573
# [426]	validation_0-auc:0.84571
# [427]	validation_0-auc:0.84582
# [428]	validation_0-auc:0.84571
# [429]	validation_0-auc:0.84553
# [430]	validation_0-auc:0.84532
# [431]	validation_0-auc:0.84560
# [432]	validation_0-auc:0.84565
# [433]	validation_0-auc:0.84565
# [434]	validation_0-auc:0.84559
# [435]	validation_0-auc:0.84597
# [436]	validation_0-auc:0.84599
# [437]	validation_0-auc:0.84630
# [438]	validation_0-auc:0.84612
# [439]	validation_0-auc:0.84609
# [440]	validation_0-auc:0.84644
# [441]	validation_0-auc:0.84699
# [442]	validation_0-auc:0.84684
# [443]	validation_0-auc:0.84669
# [444]	validation_0-auc:0.84671
# [445]	validation_0-auc:0.84657
# [446]	validation_0-auc:0.84654
# [447]	validation_0-auc:0.84652
# [448]	validation_0-auc:0.84637
# [449]	validation_0-auc:0.84634
# [450]	validation_0-auc:0.84638
# [451]	validation_0-auc:0.84639
# [452]	validation_0-auc:0.84633
# [453]	validation_0-auc:0.84629
# [454]	validation_0-auc:0.84617
# [455]	validation_0-auc:0.84611
# [456]	validation_0-auc:0.84604
# [457]	validation_0-auc:0.84604
# [458]	validation_0-auc:0.84590
# [459]	validation_0-auc:0.84605
# [460]	validation_0-auc:0.84606
# [461]	validation_0-auc:0.84692
# [462]	validation_0-auc:0.84687
# [463]	validation_0-auc:0.84681
# [464]	validation_0-auc:0.84722
# [465]	validation_0-auc:0.84708
# [466]	validation_0-auc:0.84708
# [467]	validation_0-auc:0.84703
# [468]	validation_0-auc:0.84688
# [469]	validation_0-auc:0.84695
# [470]	validation_0-auc:0.84689
# [471]	validation_0-auc:0.84681
# [472]	validation_0-auc:0.84683
# [473]	validation_0-auc:0.84669
# [474]	validation_0-auc:0.84657
# [475]	validation_0-auc:0.84669
# [476]	validation_0-auc:0.84660
# [477]	validation_0-auc:0.84659
# [478]	validation_0-auc:0.84669
# [479]	validation_0-auc:0.84666
# [480]	validation_0-auc:0.84674
# [481]	validation_0-auc:0.84703
# [482]	validation_0-auc:0.84737
# [483]	validation_0-auc:0.84734
# [484]	validation_0-auc:0.84711
# [485]	validation_0-auc:0.84711
# [486]	validation_0-auc:0.84709
# [487]	validation_0-auc:0.84746
# [488]	validation_0-auc:0.84747
# [489]	validation_0-auc:0.84754
# [490]	validation_0-auc:0.84742
# [491]	validation_0-auc:0.84754
# [492]	validation_0-auc:0.84748
# [493]	validation_0-auc:0.84760
# [494]	validation_0-auc:0.84754
# [495]	validation_0-auc:0.84738
# [496]	validation_0-auc:0.84725
# [497]	validation_0-auc:0.84729
# [498]	validation_0-auc:0.84730
# [499]	validation_0-auc:0.84727
# [500]	validation_0-auc:0.84714
# [501]	validation_0-auc:0.84707
# [502]	validation_0-auc:0.84713
# [503]	validation_0-auc:0.84706
# [504]	validation_0-auc:0.84710
# [505]	validation_0-auc:0.84712
# [506]	validation_0-auc:0.84705
# [507]	validation_0-auc:0.84762
# [508]	validation_0-auc:0.84775
# [509]	validation_0-auc:0.84757
# [510]	validation_0-auc:0.84741
# [511]	validation_0-auc:0.84742
# [512]	validation_0-auc:0.84751
# [513]	validation_0-auc:0.84749
# [514]	validation_0-auc:0.84760
# [515]	validation_0-auc:0.84760
# [516]	validation_0-auc:0.84752
# [517]	validation_0-auc:0.84737
# [518]	validation_0-auc:0.84739
# [519]	validation_0-auc:0.84730
# [520]	validation_0-auc:0.84729
# [521]	validation_0-auc:0.84753
# [522]	validation_0-auc:0.84759
# [523]	validation_0-auc:0.84759
# [524]	validation_0-auc:0.84805
# [525]	validation_0-auc:0.84827
# [526]	validation_0-auc:0.84823
# [527]	validation_0-auc:0.84811
# [528]	validation_0-auc:0.84803
# [529]	validation_0-auc:0.84803
# [530]	validation_0-auc:0.84800
# [531]	validation_0-auc:0.84805
# [532]	validation_0-auc:0.84804
# [533]	validation_0-auc:0.84812
# [534]	validation_0-auc:0.84825
# [535]	validation_0-auc:0.84814
# [536]	validation_0-auc:0.84840
# [537]	validation_0-auc:0.84838
# [538]	validation_0-auc:0.84832
# [539]	validation_0-auc:0.84869
# [540]	validation_0-auc:0.84868
# [541]	validation_0-auc:0.84867
# [542]	validation_0-auc:0.84867
# [543]	validation_0-auc:0.84867
# [544]	validation_0-auc:0.84868
# [545]	validation_0-auc:0.84865
# [546]	validation_0-auc:0.84864
# [547]	validation_0-auc:0.84859
# [548]	validation_0-auc:0.84858
# [549]	validation_0-auc:0.84855
# [550]	validation_0-auc:0.84843
# [551]	validation_0-auc:0.84821
# [552]	validation_0-auc:0.84811
# [553]	validation_0-auc:0.84849
# [554]	validation_0-auc:0.84852
# [555]	validation_0-auc:0.84850
# [556]	validation_0-auc:0.84855
# [557]	validation_0-auc:0.84862
# [558]	validation_0-auc:0.84862
# [559]	validation_0-auc:0.84858
# [560]	validation_0-auc:0.84890
# [561]	validation_0-auc:0.84884
# [562]	validation_0-auc:0.84880
# [563]	validation_0-auc:0.84880
# [564]	validation_0-auc:0.84903
# [565]	validation_0-auc:0.84896
# [566]	validation_0-auc:0.84880
# [567]	validation_0-auc:0.84876
# [568]	validation_0-auc:0.84875
# [569]	validation_0-auc:0.84869
# [570]	validation_0-auc:0.84877
# [571]	validation_0-auc:0.84865
# [572]	validation_0-auc:0.84867
# [573]	validation_0-auc:0.84878
# [574]	validation_0-auc:0.84878
# [575]	validation_0-auc:0.84869
# [576]	validation_0-auc:0.84871
# [577]	validation_0-auc:0.84864
# [578]	validation_0-auc:0.84882
# [579]	validation_0-auc:0.84871
# [580]	validation_0-auc:0.84862
# [581]	validation_0-auc:0.84849
# [582]	validation_0-auc:0.84843
# [583]	validation_0-auc:0.84841
# [584]	validation_0-auc:0.84842
# [585]	validation_0-auc:0.84860
# [586]	validation_0-auc:0.84861
# [587]	validation_0-auc:0.84854
# [588]	validation_0-auc:0.84852
# [589]	validation_0-auc:0.84849
# [590]	validation_0-auc:0.84882
# [591]	validation_0-auc:0.84876
# [592]	validation_0-auc:0.84872
# [593]	validation_0-auc:0.84867
# [594]	validation_0-auc:0.84881
# [595]	validation_0-auc:0.84854
# [596]	validation_0-auc:0.84843
# [597]	validation_0-auc:0.84847
# [598]	validation_0-auc:0.84852
# [599]	validation_0-auc:0.84878
# [600]	validation_0-auc:0.84891
# [601]	validation_0-auc:0.84894
# [602]	validation_0-auc:0.84891
# [603]	validation_0-auc:0.84893
# [604]	validation_0-auc:0.84889
# [605]	validation_0-auc:0.84875
# [606]	validation_0-auc:0.84871
# [607]	validation_0-auc:0.84868
# [608]	validation_0-auc:0.84865
# [609]	validation_0-auc:0.84855
# [610]	validation_0-auc:0.84856
# [611]	validation_0-auc:0.84841
# [612]	validation_0-auc:0.84839
# [613]	validation_0-auc:0.84835
# [614]	validation_0-auc:0.84831
# [615]	validation_0-auc:0.84883
# [616]	validation_0-auc:0.84882
# [617]	validation_0-auc:0.84875
# [618]	validation_0-auc:0.84871
# [619]	validation_0-auc:0.84866
# [620]	validation_0-auc:0.84856
# [621]	validation_0-auc:0.84852
# [622]	validation_0-auc:0.84859
# [623]	validation_0-auc:0.84853
# [624]	validation_0-auc:0.84852
# [625]	validation_0-auc:0.84853
# [626]	validation_0-auc:0.84846
# [627]	validation_0-auc:0.84869
# [628]	validation_0-auc:0.84865
# [629]	validation_0-auc:0.84870
# [630]	validation_0-auc:0.84866
# [631]	validation_0-auc:0.84884
# [632]	validation_0-auc:0.84879
# [633]	validation_0-auc:0.84868
# [634]	validation_0-auc:0.84868
# [635]	validation_0-auc:0.84865
# [636]	validation_0-auc:0.84856
# [637]	validation_0-auc:0.84855
# [638]	validation_0-auc:0.84881
# [639]	validation_0-auc:0.84883
# [640]	validation_0-auc:0.84873
# [641]	validation_0-auc:0.84885
# [642]	validation_0-auc:0.84905
# [643]	validation_0-auc:0.84927
# [644]	validation_0-auc:0.84947
# [645]	validation_0-auc:0.84955
# [646]	validation_0-auc:0.84952
# [647]	validation_0-auc:0.84952
# [648]	validation_0-auc:0.84939
# [649]	validation_0-auc:0.84947
# [650]	validation_0-auc:0.84943
# [651]	validation_0-auc:0.84990
# [652]	validation_0-auc:0.84987
# [653]	validation_0-auc:0.84985
# [654]	validation_0-auc:0.85024
# [655]	validation_0-auc:0.85014
# [656]	validation_0-auc:0.85004
# [657]	validation_0-auc:0.85020
# [658]	validation_0-auc:0.85040
# [659]	validation_0-auc:0.85025
# [660]	validation_0-auc:0.85056
# [661]	validation_0-auc:0.85060
# [662]	validation_0-auc:0.85082
# [663]	validation_0-auc:0.85073
# [664]	validation_0-auc:0.85075
# [665]	validation_0-auc:0.85080
# [666]	validation_0-auc:0.85083
# [667]	validation_0-auc:0.85077
# [668]	validation_0-auc:0.85081
# [669]	validation_0-auc:0.85078
# [670]	validation_0-auc:0.85081
# [671]	validation_0-auc:0.85081
# [672]	validation_0-auc:0.85075
# [673]	validation_0-auc:0.85069
# [674]	validation_0-auc:0.85057
# [675]	validation_0-auc:0.85082
# [676]	validation_0-auc:0.85082
# [677]	validation_0-auc:0.85093
# [678]	validation_0-auc:0.85098
# [679]	validation_0-auc:0.85082
# [680]	validation_0-auc:0.85085
# [681]	validation_0-auc:0.85084
# [682]	validation_0-auc:0.85083
# [683]	validation_0-auc:0.85078
# [684]	validation_0-auc:0.85074
# [685]	validation_0-auc:0.85073
# [686]	validation_0-auc:0.85072
# [687]	validation_0-auc:0.85115
# [688]	validation_0-auc:0.85126
# [689]	validation_0-auc:0.85124
# [690]	validation_0-auc:0.85129
# [691]	validation_0-auc:0.85137
# [692]	validation_0-auc:0.85133
# [693]	validation_0-auc:0.85129
# [694]	validation_0-auc:0.85121
# [695]	validation_0-auc:0.85111
# [696]	validation_0-auc:0.85115
# [697]	validation_0-auc:0.85111
# [698]	validation_0-auc:0.85105
# [699]	validation_0-auc:0.85105
# [700]	validation_0-auc:0.85097
# [701]	validation_0-auc:0.85082
# [702]	validation_0-auc:0.85071
# [703]	validation_0-auc:0.85070
# [704]	validation_0-auc:0.85072
# [705]	validation_0-auc:0.85073
# [706]	validation_0-auc:0.85066
# [707]	validation_0-auc:0.85077
# [708]	validation_0-auc:0.85075
# [709]	validation_0-auc:0.85072
# [710]	validation_0-auc:0.85076
# [711]	validation_0-auc:0.85061
# [712]	validation_0-auc:0.85060
# [713]	validation_0-auc:0.85059
# [714]	validation_0-auc:0.85052
# [715]	validation_0-auc:0.85069
# [716]	validation_0-auc:0.85069
# [717]	validation_0-auc:0.85057
# [718]	validation_0-auc:0.85048
# [719]	validation_0-auc:0.85047
# [720]	validation_0-auc:0.85049
# [721]	validation_0-auc:0.85067
# [722]	validation_0-auc:0.85079
# [723]	validation_0-auc:0.85083
# [724]	validation_0-auc:0.85061
# [725]	validation_0-auc:0.85075
# [726]	validation_0-auc:0.85075
# [727]	validation_0-auc:0.85063
# [728]	validation_0-auc:0.85067
# [729]	validation_0-auc:0.85062
# [730]	validation_0-auc:0.85064
# [731]	validation_0-auc:0.85059
# [732]	validation_0-auc:0.85058
# [733]	validation_0-auc:0.85075
# [734]	validation_0-auc:0.85089
# [735]	validation_0-auc:0.85073
# [736]	validation_0-auc:0.85073
# [737]	validation_0-auc:0.85070
# [738]	validation_0-auc:0.85068
# [739]	validation_0-auc:0.85056
# [740]	validation_0-auc:0.85063
# [741]	validation_0-auc:0.85058
# [742]	validation_0-auc:0.85058
# [743]	validation_0-auc:0.85052
# [744]	validation_0-auc:0.85069
# [745]	validation_0-auc:0.85068
# [746]	validation_0-auc:0.85060
# [747]	validation_0-auc:0.85055
# [748]	validation_0-auc:0.85055
# [749]	validation_0-auc:0.85055
# [750]	validation_0-auc:0.85045
# [751]	validation_0-auc:0.85073
# [752]	validation_0-auc:0.85077
# [753]	validation_0-auc:0.85068
# [754]	validation_0-auc:0.85090
# [755]	validation_0-auc:0.85092
# [756]	validation_0-auc:0.85151
# [757]	validation_0-auc:0.85147
# [758]	validation_0-auc:0.85146
# [759]	validation_0-auc:0.85143
# [760]	validation_0-auc:0.85138
# [761]	validation_0-auc:0.85132
# [762]	validation_0-auc:0.85165
# [763]	validation_0-auc:0.85167
# [764]	validation_0-auc:0.85168
# [765]	validation_0-auc:0.85164
# [766]	validation_0-auc:0.85163
# [767]	validation_0-auc:0.85163
# [768]	validation_0-auc:0.85204
# [769]	validation_0-auc:0.85236
# [770]	validation_0-auc:0.85246
# [771]	validation_0-auc:0.85246
# [772]	validation_0-auc:0.85238
# [773]	validation_0-auc:0.85237
# [774]	validation_0-auc:0.85240
# [775]	validation_0-auc:0.85236
# [776]	validation_0-auc:0.85229
# [777]	validation_0-auc:0.85223
# [778]	validation_0-auc:0.85214
# [779]	validation_0-auc:0.85226
# [780]	validation_0-auc:0.85224
# [781]	validation_0-auc:0.85220
# [782]	validation_0-auc:0.85217
# [783]	validation_0-auc:0.85221
# [784]	validation_0-auc:0.85215
# [785]	validation_0-auc:0.85214
# [786]	validation_0-auc:0.85216
# [787]	validation_0-auc:0.85201
# [788]	validation_0-auc:0.85196
# [789]	validation_0-auc:0.85194
# [790]	validation_0-auc:0.85193
# [791]	validation_0-auc:0.85188
# [792]	validation_0-auc:0.85180
# [793]	validation_0-auc:0.85181
# [794]	validation_0-auc:0.85189
# [795]	validation_0-auc:0.85205
# [796]	validation_0-auc:0.85204
# [797]	validation_0-auc:0.85206
# [798]	validation_0-auc:0.85205
# [799]	validation_0-auc:0.85202
# [800]	validation_0-auc:0.85194
# [801]	validation_0-auc:0.85195
# [802]	validation_0-auc:0.85189
# [803]	validation_0-auc:0.85196
# [804]	validation_0-auc:0.85191
# [805]	validation_0-auc:0.85186
# [806]	validation_0-auc:0.85189
# [807]	validation_0-auc:0.85185
# [808]	validation_0-auc:0.85172
# [809]	validation_0-auc:0.85169
# [810]	validation_0-auc:0.85165
# [811]	validation_0-auc:0.85167
# [812]	validation_0-auc:0.85159
# [813]	validation_0-auc:0.85160
# [814]	validation_0-auc:0.85155
# [815]	validation_0-auc:0.85143
# [816]	validation_0-auc:0.85141
# [817]	validation_0-auc:0.85141
# [818]	validation_0-auc:0.85162
# [819]	validation_0-auc:0.85158
# [820]	validation_0-auc:0.85157
# [821]	validation_0-auc:0.85157
# [822]	validation_0-auc:0.85154
# [823]	validation_0-auc:0.85154
# [824]	validation_0-auc:0.85158
# [825]	validation_0-auc:0.85159
# [826]	validation_0-auc:0.85169
# [827]	validation_0-auc:0.85169
# [828]	validation_0-auc:0.85169
# [829]	validation_0-auc:0.85171
# [830]	validation_0-auc:0.85164
# [831]	validation_0-auc:0.85162
# [832]	validation_0-auc:0.85160
# [833]	validation_0-auc:0.85160
# [834]	validation_0-auc:0.85175
# [835]	validation_0-auc:0.85184
# [836]	validation_0-auc:0.85189
# [837]	validation_0-auc:0.85180
# [838]	validation_0-auc:0.85179
# [839]	validation_0-auc:0.85183
# [840]	validation_0-auc:0.85188
# [841]	validation_0-auc:0.85190
# [842]	validation_0-auc:0.85180
# [843]	validation_0-auc:0.85183
# [844]	validation_0-auc:0.85181
# [845]	validation_0-auc:0.85189
# [846]	validation_0-auc:0.85181
# [847]	validation_0-auc:0.85173
# [848]	validation_0-auc:0.85170
# [849]	validation_0-auc:0.85160
# [850]	validation_0-auc:0.85146
# [851]	validation_0-auc:0.85143
# [852]	validation_0-auc:0.85136
# [853]	validation_0-auc:0.85138
# [854]	validation_0-auc:0.85133
# [855]	validation_0-auc:0.85135
# [856]	validation_0-auc:0.85129
# [857]	validation_0-auc:0.85129
# [858]	validation_0-auc:0.85131
# [859]	validation_0-auc:0.85179
# [860]	validation_0-auc:0.85174
# [861]	validation_0-auc:0.85175
# [862]	validation_0-auc:0.85168
# [863]	validation_0-auc:0.85167
# [864]	validation_0-auc:0.85164
# [865]	validation_0-auc:0.85157
# [866]	validation_0-auc:0.85175
# [867]	validation_0-auc:0.85176
# [868]	validation_0-auc:0.85175
# [869]	validation_0-auc:0.85166
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=None, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=1000, n_jobs=-1,
#               num_parallel_tree=None, random_state=42, ...)

# %%
val_res = 1 -xgboost.predict_proba(X_val)[:,0]

# %%
roc_auc_score(y_val,val_res)
# Out:
# 0.8524601219113352

# %%
test_df = pd.read_csv( F'./data/{feature_set}/test_features.csv')

# %%
test_res = 1 -xgboost.predict_proba(test_df.drop(columns=['TX_ID']))[:,0]

# %%
test_res
# Out:
# array([0.00145596, 0.00751865, 0.00122434, ..., 0.00879544, 0.00192368,
#        0.0002476 ], dtype=float32)

# %%
test_df['TX_FRAUD']  = test_res

# %%
submission
# Out:
#                                           TX_ID  TX_FRAUD
# 0      09324d812ba7915c3f791e973db293ad50db70d8  0.001456
# 1      365385787bc3da985acb1f5c120c6d0831dc8734  0.007519
# 2      0c952ffc309601a50bd11cbbbfcacd887f99c14c  0.001224
# 3      bfbfcd0e8b0b24dd32743390a500bbf3d815856a  0.024206
# 4      0052bebc8c3e21ef6a195eaecc75376fb53b49ad  0.002385
# ...                                         ...       ...
# 71133  28ae334063e4f58ffc8b47789d911b25915b72a3  0.032827
# 71134  05b33d08d2158971856c3cddd3a7ad161d1fa350  0.001076
# 71135  9ac904a006491900fb0f26e98aeea4fe24aa37a8  0.008795
# 71136  2f1693aeb0e7b26a3f0d2634da09b3d2238329b9  0.001924
# 71137  e7b925f2ccebf6c5a927efc190083892c0a18312  0.000248
#
# [71138 rows x 2 columns]

# %%
dict = {'TX_ID':['ddaa070acea087eae360225e92c1609cea905e43'],
        'TX_FRAUD':[0]
       }
df2 = pd.DataFrame(dict)

# %%
submission = pd.concat([submission,df2],ignore_index = True)

# %%
test_trans = pd.read_csv( F'./data/transactions_test.csv')

# %%
test_trans = test_trans['TX_ID']

# %%
submission.set_index('TX_ID',inplace=True)
submission = submission.reindex(index =test_trans)

# %%
location = 'results'
submission.to_csv(F'./{location}/results_4_xgb.csv',index=True)
